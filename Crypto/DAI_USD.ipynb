# %%
#Importing necessary libraries for training the model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # for ploting graphs
import plotly.express as px # for ploting graphs
import plotly.graph_objects as go # for ploting graphs
from plotly.subplots import make_subplots # to create the subplots
from datetime import datetime # for extracting data and time 
from sklearn.model_selection import train_test_split # for separating the training and testing data
from sklearn.linear_model import LinearRegression # for model creation
import joblib # used to save model in .pkl format

# %%
DAI = pd.read_csv("DAI-USD.csv")
DAI
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2019-11-22  0.997358  1.026548  0.972164  0.992598   0.992598
# 1     2019-11-23  0.992184  1.028747  0.988341  1.016282   1.016282
# 2     2019-11-24  1.016288  1.035136  0.995609  1.002270   1.002270
# 3     2019-11-25  1.001289  1.034708  0.984805  1.007021   1.007021
# 4     2019-11-26  1.007208  1.031428  0.991767  1.006096   1.006096
# ...          ...       ...       ...       ...       ...        ...
# 1397  2023-09-19  0.999840  1.001035  0.998742  1.000052   1.000052
# 1398  2023-09-20  1.000025  1.000719  0.998486  0.999682   0.999682
# 1399  2023-09-21       NaN       NaN       NaN       NaN        NaN
# 1400  2023-09-22       NaN       NaN       NaN       NaN        NaN
# 1401  2023-09-23  0.999891  1.000326  0.999526  0.999958   0.999958
#
#            Volume
# 0       2104541.0
# 1        311283.0
# 2        255060.0
# 3        958777.0
# 4        217385.0
# ...           ...
# 1397  106018722.0
# 1398   83337762.0
# 1399          NaN
# 1400          NaN
# 1401  115597584.0
#
# [1402 rows x 7 columns]

# %% [markdown]
# # Pre-processing

# %%
#Dropping unnecessary columns
DAI.drop(['Adj Close'], axis=1, inplace=True)
DAI
# Out:
#             Date      Open      High       Low     Close       Volume
# 0     2019-11-22  0.997358  1.026548  0.972164  0.992598    2104541.0
# 1     2019-11-23  0.992184  1.028747  0.988341  1.016282     311283.0
# 2     2019-11-24  1.016288  1.035136  0.995609  1.002270     255060.0
# 3     2019-11-25  1.001289  1.034708  0.984805  1.007021     958777.0
# 4     2019-11-26  1.007208  1.031428  0.991767  1.006096     217385.0
# ...          ...       ...       ...       ...       ...          ...
# 1397  2023-09-19  0.999840  1.001035  0.998742  1.000052  106018722.0
# 1398  2023-09-20  1.000025  1.000719  0.998486  0.999682   83337762.0
# 1399  2023-09-21       NaN       NaN       NaN       NaN          NaN
# 1400  2023-09-22       NaN       NaN       NaN       NaN          NaN
# 1401  2023-09-23  0.999891  1.000326  0.999526  0.999958  115597584.0
#
# [1402 rows x 6 columns]

# %%
DAI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1402 entries, 0 to 1401
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1402 non-null   object
#  1   Open    1400 non-null   float64
#  2   High    1400 non-null   float64
#  3   Low     1400 non-null   float64
#  4   Close   1400 non-null   float64
#  5   Volume  1400 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 65.8+ KB

# %%
DAI.isnull().sum()
# Out:
# Date      0
# Open      2
# High      2
# Low       2
# Close     2
# Volume    2
# dtype: int64

# %%
DAI.duplicated().sum()
# Out:
# 0

# %%
DAI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1402 entries, 0 to 1401
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1402 non-null   object
#  1   Open    1400 non-null   float64
#  2   High    1400 non-null   float64
#  3   Low     1400 non-null   float64
#  4   Close   1400 non-null   float64
#  5   Volume  1400 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 65.8+ KB

# %% [markdown]
# # Visualizations
#
# ## i) Graph for Open Prices

# %%
import plotly.graph_objects as go

plt.figure(figsize=(14, 6))
fig = px.line(DAI.Open,x=DAI.Date, y='Open', labels={'x': 'Date', 'y': 'Price'}, title='Open Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.update_xaxes(tickfont=dict(color='#B468FF'))  # Set x-axis label color to light purple
fig.update_yaxes(tickfont=dict(color='#B468FF'))
fig.update_layout(
    paper_bgcolor='#180736',  # Set the background color to white
    plot_bgcolor='#180736',  # Set the background color to white
    template="plotly_dark"  # Use the "plotly_dark" template
)
fig.update_traces(line=dict(color='#B468FF'))

fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %% [markdown]
# ## i) Graph for High Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(DAI.High,x=DAI.Date, y='High', labels={'x': 'Date', 'y': 'Price'}, title='High Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iii) Graph for Low Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(DAI.Low,x=DAI.Date, y='Low', labels={'x': 'Date', 'y': 'Price'}, title='Low Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iv) Graph for Close Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(DAI.Close,x=DAI.Date, y='Close', labels={'x': 'Date', 'y': 'Price'}, title='Close Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ### Now, creating plots for High and Low Column Values
#
# #### These are subplots

# %%
#Creating Subplots for high and low columns

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# Second subplot (High Price)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['High'], mode='lines', name='High Price'), row=1, col=1)
fig.update_yaxes(title_text="High Price", row=1, col=1)

# Third subplot (Low Price)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['Low'], mode='lines', name='High Price'), row=2, col=1)
fig.update_yaxes(title_text="Low Price", row=2, col=1)

# Fourth subplot(High and Low Prices)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['High'], mode='lines', name='High Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['Low'], mode='lines', name='Low Price'), row=3, col=1)
fig.update_yaxes(title_text="High and Low Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="High, Low and High & Low Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %% [markdown]
# ### Now, subplots for Open and Closed Prices

# %%
#Subplots for open and close prices

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# First subplot (Open Price)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['Open'], mode='lines', name='Open Price'), row=1, col=1)
fig.update_yaxes(title_text="Open Price", row=1, col=1)

# Second subplot (Close Price)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['Close'], mode='lines', name='Close Price'), row=2, col=1)
fig.update_yaxes(title_text="Close Price", row=2, col=1)

# Third subplot(Open and Close Prices)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['Open'], mode='lines', name='Open Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=DAI['Date'], y=DAI['Close'], mode='lines', name='Close Price'), row=3, col=1)
fig.update_yaxes(title_text="Open and Close Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="Open, Close and Open & Close Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %%
# making output column one day ahead of the closing price column
DAI['Target_Price'] = DAI['Close'].shift(-1)
DAI
# Out:
#             Date      Open      High       Low     Close       Volume  \
# 0     2019-11-22  0.997358  1.026548  0.972164  0.992598    2104541.0
# 1     2019-11-23  0.992184  1.028747  0.988341  1.016282     311283.0
# 2     2019-11-24  1.016288  1.035136  0.995609  1.002270     255060.0
# 3     2019-11-25  1.001289  1.034708  0.984805  1.007021     958777.0
# 4     2019-11-26  1.007208  1.031428  0.991767  1.006096     217385.0
# ...          ...       ...       ...       ...       ...          ...
# 1397  2023-09-19  0.999840  1.001035  0.998742  1.000052  106018722.0
# 1398  2023-09-20  1.000025  1.000719  0.998486  0.999682   83337762.0
# 1399  2023-09-21       NaN       NaN       NaN       NaN          NaN
# 1400  2023-09-22       NaN       NaN       NaN       NaN          NaN
# 1401  2023-09-23  0.999891  1.000326  0.999526  0.999958  115597584.0
#
#       Target_Price
# 0         1.016282
# 1         1.002270
# 2         1.007021
# 3         1.006096
# 4         0.997034
# ...            ...
# 1397      0.999682
# 1398           NaN
# 1399           NaN
# 1400      0.999958
# 1401           NaN
#
# [1402 rows x 7 columns]

# %%
DAI.isnull().sum()
# Out:
# Date            0
# Open            2
# High            2
# Low             2
# Close           2
# Volume          2
# Target_Price    3
# dtype: int64

# %%
DAI.dropna(inplace=True)

# %%
DAI.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    0
# dtype: int64

# %%
# input features
X_DAI=DAI[['Open', 'Close']]

# output features
y_DAI=DAI['Target_Price']

# %% [markdown]
# # Training and Testing the Model
#
# ## We will give 0.10 % data to our model for testing to make accurate and close predictions

# %%
X_DAI_train, X_DAI_test, y_DAI_train, y_DAI_test=train_test_split(X_DAI, y_DAI, test_size=.01, random_state=50)

# %%
model_DAI=LinearRegression()
model_DAI.fit(X_DAI_train, y_DAI_train)
# Out:
# LinearRegression()

# %%
model_DAI.score(X_DAI_test, y_DAI_test)
# Out:
# 0.8094919344958337

# %%
DAI_model=joblib.dump(model_DAI,"DAI_predictions.pkl")

# %%
DAI.tail(1)
# Out:
#             Date     Open      High       Low     Close       Volume  \
# 1397  2023-09-19  0.99984  1.001035  0.998742  1.000052  106018722.0
#
#       Target_Price
# 1397      0.999682

# %%
DAI_model_predictions=joblib.load("DAI_predictions.pkl")

DAI_last_Open=float(input("Enter the last Open value: "))
print("You entered DAI_last_Open value: ", DAI_last_Open)

DAI_last_Close=float(input("Enter the last Close value: "))
print("You entered DAI_last_Close value: ", DAI_last_Close)
print(" ")

DAI_Input=pd.DataFrame({"Open": [DAI_last_Open], "Close": [DAI_last_Close]})
DAI_future_pred=DAI_model_predictions.predict(DAI_Input)
    
print("Your predicted value of DAI coin is==> ", DAI_future_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alishba athar\OneDrive\Desktop\Crypto\DAI_USD.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/DAI_USD.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> DAI_model_predictions=joblib.load("DAI_predictions.pkl")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/DAI_USD.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> DAI_last_Open=float(input("Enter the last Open value: "))
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/DAI_USD.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> print("You entered DAI_last_Open value: ", DAI_last_Open)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/DAI_USD.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> DAI_last_Close=float(input("Enter the last Close value: "))
#
# ValueError: could not convert string to float: ''
