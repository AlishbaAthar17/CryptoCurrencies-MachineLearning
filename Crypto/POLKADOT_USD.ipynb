# %%
#Importing necessary libraries for training the model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # for ploting graphs
import plotly.express as px # for ploting graphs
import plotly.graph_objects as go # for ploting graphs
from plotly.subplots import make_subplots # to create the subplots
from datetime import datetime # for extracting data and time 
from sklearn.model_selection import train_test_split # for separating the training and testing data
from sklearn.linear_model import LinearRegression # for model creation
import joblib # used to save model in .pkl format

# %%
POLKADOT = pd.read_csv("DOT-USD.csv")
POLKADOT
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2020-08-20  2.787857  3.077784  2.692896  2.900080   2.900080
# 1     2020-08-21  2.896923  3.090093  2.730919  2.875028   2.875028
# 2     2020-08-22  2.878570  4.510613  2.816762  4.484690   4.484690
# 3     2020-08-23  4.487058  4.487058  3.716271  3.967066   3.967066
# 4     2020-08-24  3.987413  4.783158  3.812670  4.602614   4.602614
# ...          ...       ...       ...       ...       ...        ...
# 1125  2023-09-19  4.108263  4.163175  4.087499  4.156242   4.156242
# 1126  2023-09-20       NaN       NaN       NaN       NaN        NaN
# 1127  2023-09-21       NaN       NaN       NaN       NaN        NaN
# 1128  2023-09-22       NaN       NaN       NaN       NaN        NaN
# 1129  2023-09-23  4.022177  4.035906  4.007245  4.012949   4.012949
#
#            Volume
# 0      48819867.0
# 1      49313137.0
# 2     485801096.0
# 3     320749483.0
# 4     407690171.0
# ...           ...
# 1125   98635960.0
# 1126          NaN
# 1127          NaN
# 1128          NaN
# 1129   68894040.0
#
# [1130 rows x 7 columns]

# %% [markdown]
# # Pre-processing

# %%
#Dropping unnecessary columns
POLKADOT.drop(['Adj Close'], axis=1, inplace=True)
POLKADOT
# Out:
#             Date      Open      High       Low     Close       Volume
# 0     2020-08-20  2.787857  3.077784  2.692896  2.900080   48819867.0
# 1     2020-08-21  2.896923  3.090093  2.730919  2.875028   49313137.0
# 2     2020-08-22  2.878570  4.510613  2.816762  4.484690  485801096.0
# 3     2020-08-23  4.487058  4.487058  3.716271  3.967066  320749483.0
# 4     2020-08-24  3.987413  4.783158  3.812670  4.602614  407690171.0
# ...          ...       ...       ...       ...       ...          ...
# 1125  2023-09-19  4.108263  4.163175  4.087499  4.156242   98635960.0
# 1126  2023-09-20       NaN       NaN       NaN       NaN          NaN
# 1127  2023-09-21       NaN       NaN       NaN       NaN          NaN
# 1128  2023-09-22       NaN       NaN       NaN       NaN          NaN
# 1129  2023-09-23  4.022177  4.035906  4.007245  4.012949   68894040.0
#
# [1130 rows x 6 columns]

# %%
POLKADOT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1130 non-null   object
#  1   Open    1127 non-null   float64
#  2   High    1127 non-null   float64
#  3   Low     1127 non-null   float64
#  4   Close   1127 non-null   float64
#  5   Volume  1127 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 53.1+ KB

# %%
POLKADOT.isnull().sum()
# Out:
# Date      0
# Open      3
# High      3
# Low       3
# Close     3
# Volume    3
# dtype: int64

# %%
POLKADOT.duplicated().sum()
# Out:
# 0

# %%
POLKADOT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1130 non-null   object
#  1   Open    1127 non-null   float64
#  2   High    1127 non-null   float64
#  3   Low     1127 non-null   float64
#  4   Close   1127 non-null   float64
#  5   Volume  1127 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 53.1+ KB

# %% [markdown]
# # Visualizations
#
# ## i) Graph for Open Prices

# %%
import plotly.graph_objects as go

plt.figure(figsize=(14, 6))
fig = px.line(POLKADOT.Open,x=POLKADOT.Date, y='Open', labels={'x': 'Date', 'y': 'Price'}, title='Open Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.update_xaxes(tickfont=dict(color='#B468FF'))  # Set x-axis label color to light purple
fig.update_yaxes(tickfont=dict(color='#B468FF'))
fig.update_layout(
    paper_bgcolor='#180736',  # Set the background color to white
    plot_bgcolor='#180736',  # Set the background color to white
    template="plotly_dark"  # Use the "plotly_dark" template
)
fig.update_traces(line=dict(color='#B468FF'))

fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)

fig.show()

# %% [markdown]
# ## i) Graph for High Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(POLKADOT.High,x=POLKADOT.Date, y='High', labels={'x': 'Date', 'y': 'Price'}, title='High Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iii) Graph for Low Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(POLKADOT.Low,x=POLKADOT.Date, y='Low', labels={'x': 'Date', 'y': 'Price'}, title='Low Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iv) Graph for Close Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(POLKADOT.Close,x=POLKADOT.Date, y='Close', labels={'x': 'Date', 'y': 'Price'}, title='Close Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ### Now, creating plots for High and Low Column Values
#
# #### These are subplots

# %%
#Creating Subplots for high and low columns

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# Second subplot (High Price)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['High'], mode='lines', name='High Price'), row=1, col=1)
fig.update_yaxes(title_text="High Price", row=1, col=1)

# Third subplot (Low Price)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['Low'], mode='lines', name='High Price'), row=2, col=1)
fig.update_yaxes(title_text="Low Price", row=2, col=1)

# Fourth subplot(High and Low Prices)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['High'], mode='lines', name='High Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['Low'], mode='lines', name='Low Price'), row=3, col=1)
fig.update_yaxes(title_text="High and Low Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="High, Low and High & Low Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %% [markdown]
# ### Now, subplots for Open and Closed Prices

# %%
#Subplots for open and close prices

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# First subplot (Open Price)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['Open'], mode='lines', name='Open Price'), row=1, col=1)
fig.update_yaxes(title_text="Open Price", row=1, col=1)

# Second subplot (Close Price)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['Close'], mode='lines', name='Close Price'), row=2, col=1)
fig.update_yaxes(title_text="Close Price", row=2, col=1)

# Third subplot(Open and Close Prices)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['Open'], mode='lines', name='Open Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=POLKADOT['Date'], y=POLKADOT['Close'], mode='lines', name='Close Price'), row=3, col=1)
fig.update_yaxes(title_text="Open and Close Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="Open, Close and Open & Close Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %%
# making output column one day ahead of the closing price column
POLKADOT['Target_Price'] = POLKADOT['Close'].shift(-1)
POLKADOT
# Out:
#             Date      Open      High       Low     Close       Volume  \
# 0     2020-08-20  2.787857  3.077784  2.692896  2.900080   48819867.0
# 1     2020-08-21  2.896923  3.090093  2.730919  2.875028   49313137.0
# 2     2020-08-22  2.878570  4.510613  2.816762  4.484690  485801096.0
# 3     2020-08-23  4.487058  4.487058  3.716271  3.967066  320749483.0
# 4     2020-08-24  3.987413  4.783158  3.812670  4.602614  407690171.0
# ...          ...       ...       ...       ...       ...          ...
# 1125  2023-09-19  4.108263  4.163175  4.087499  4.156242   98635960.0
# 1126  2023-09-20       NaN       NaN       NaN       NaN          NaN
# 1127  2023-09-21       NaN       NaN       NaN       NaN          NaN
# 1128  2023-09-22       NaN       NaN       NaN       NaN          NaN
# 1129  2023-09-23  4.022177  4.035906  4.007245  4.012949   68894040.0
#
#       Target_Price
# 0         2.875028
# 1         4.484690
# 2         3.967066
# 3         4.602614
# 4         5.523393
# ...            ...
# 1125           NaN
# 1126           NaN
# 1127           NaN
# 1128      4.012949
# 1129           NaN
#
# [1130 rows x 7 columns]

# %%
POLKADOT.isnull().sum()
# Out:
# Date            0
# Open            3
# High            3
# Low             3
# Close           3
# Volume          3
# Target_Price    4
# dtype: int64

# %%
POLKADOT.dropna(inplace=True)

# %%
POLKADOT.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    0
# dtype: int64

# %%
# input features
X_POLKADOT=POLKADOT[['Open', 'Close']]

# output features
y_POLKADOT=POLKADOT['Target_Price']

# %% [markdown]
# # Training and Testing the Model
#
# ## We will give 0.10 % data to our model for testing to make accurate and close predictions

# %%
X_POLKADOT_train, X_POLKADOT_test, y_POLKADOT_train, y_POLKADOT_test=train_test_split(X_POLKADOT, y_POLKADOT, test_size=.10, random_state=50)

# %%
model_POLKADOT=LinearRegression()
model_POLKADOT.fit(X_POLKADOT_train, y_POLKADOT_train)
# Out:
# LinearRegression()

# %%
model_POLKADOT.score(X_POLKADOT_test, y_POLKADOT_test)
# Out:
# 0.9866336825245507

# %%
POLKADOT_model=joblib.dump(model_POLKADOT,"POLKADOT_predictions.pkl")

# %%
POLKADOT.tail(1)
# Out:
#             Date      Open      High       Low     Close       Volume  \
# 1124  2023-09-18  4.074344  4.217762  4.031318  4.108243  107466794.0
#
#       Target_Price
# 1124      4.156242

# %%
POLKADOT_model_predictions=joblib.load("POLKADOT_predictions.pkl")

POLKADOT_last_Open=float(input("Enter the last Open value: "))
print("You entered POLKADOT_last_Open value: ", POLKADOT_last_Open)

POLKADOT_last_Close=float(input("Enter the last Close value: "))
print("You entered POLKADOT_last_Close value: ", POLKADOT_last_Close)
print(" ")

POLKADOT_Input=pd.DataFrame({"Open": [POLKADOT_last_Open], "Close": [POLKADOT_last_Close]})
POLKADOT_future_pred=POLKADOT_model_predictions.predict(POLKADOT_Input)
    
print("Your predicted value of POLKADOT coin is==> ", POLKADOT_future_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alishba athar\OneDrive\Desktop\Crypto\POLKADOT_USD.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLKADOT_USD.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> POLKADOT_model_predictions=joblib.load("POLKADOT_predictions.pkl")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLKADOT_USD.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> POLKADOT_last_Open=float(input("Enter the last Open value: "))
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLKADOT_USD.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> print("You entered POLKADOT_last_Open value: ", POLKADOT_last_Open)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLKADOT_USD.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> POLKADOT_last_Close=float(input("Enter the last Close value: "))
#
# ValueError: could not convert string to float: ''
