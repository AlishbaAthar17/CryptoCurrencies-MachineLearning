# %%
#Importing necessary libraries for training the model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # for ploting graphs
import plotly.express as px # for ploting graphs
import plotly.graph_objects as go # for ploting graphs
from plotly.subplots import make_subplots # to create the subplots
from datetime import datetime # for extracting data and time 
from sklearn.model_selection import train_test_split # for separating the training and testing data
from sklearn.linear_model import LinearRegression # for model creation
import joblib # used to save model in .pkl format

# %%
LITECOIN = pd.read_csv("LTC-USD.csv")
LITECOIN
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2018-09-25  58.021000  58.147598  54.737598  57.537601  57.537601
# 1     2018-09-26  57.449200  59.620098  56.701698  57.395500  57.395500
# 2     2018-09-27  57.450001  64.294998  56.923901  62.979401  62.979401
# 3     2018-09-28  63.171501  64.422600  60.807899  61.895100  61.895100
# 4     2018-09-29  61.643501  62.025299  59.491600  61.606899  61.606899
# ...          ...        ...        ...        ...        ...        ...
# 1822  2023-09-21  64.565125  64.967659  63.124760  64.690987  64.690987
# 1823  2023-09-22  64.691711  65.460808  64.177536  64.335403  64.335403
# 1824  2023-09-23  64.334908  65.225388  64.334908  65.080391  65.080391
# 1825  2023-09-24  65.080063  65.084198  63.540279  63.587139  63.587139
# 1826  2023-09-25  63.580563  64.574844  63.192348  64.310143  64.310143
#
#          Volume
# 0     351579000
# 1     294136000
# 2     574277000
# 3     459862000
# 4     356028000
# ...         ...
# 1822  270451760
# 1823  278551984
# 1824  240624622
# 1825  189877277
# 1826  217427200
#
# [1827 rows x 7 columns]

# %% [markdown]
# # Pre-processing

# %%
#Dropping unnecessary columns
LITECOIN.drop(['Adj Close'], axis=1, inplace=True)
LITECOIN
# Out:
#             Date       Open       High        Low      Close     Volume
# 0     2018-09-25  58.021000  58.147598  54.737598  57.537601  351579000
# 1     2018-09-26  57.449200  59.620098  56.701698  57.395500  294136000
# 2     2018-09-27  57.450001  64.294998  56.923901  62.979401  574277000
# 3     2018-09-28  63.171501  64.422600  60.807899  61.895100  459862000
# 4     2018-09-29  61.643501  62.025299  59.491600  61.606899  356028000
# ...          ...        ...        ...        ...        ...        ...
# 1822  2023-09-21  64.565125  64.967659  63.124760  64.690987  270451760
# 1823  2023-09-22  64.691711  65.460808  64.177536  64.335403  278551984
# 1824  2023-09-23  64.334908  65.225388  64.334908  65.080391  240624622
# 1825  2023-09-24  65.080063  65.084198  63.540279  63.587139  189877277
# 1826  2023-09-25  63.580563  64.574844  63.192348  64.310143  217427200
#
# [1827 rows x 6 columns]

# %%
LITECOIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1827 non-null   object
#  1   Open    1827 non-null   float64
#  2   High    1827 non-null   float64
#  3   Low     1827 non-null   float64
#  4   Close   1827 non-null   float64
#  5   Volume  1827 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 85.8+ KB

# %%
LITECOIN.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
LITECOIN.duplicated().sum()
# Out:
# 0

# %%
LITECOIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1827 non-null   object
#  1   Open    1827 non-null   float64
#  2   High    1827 non-null   float64
#  3   Low     1827 non-null   float64
#  4   Close   1827 non-null   float64
#  5   Volume  1827 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 85.8+ KB

# %% [markdown]
# # Visualizations
#
# ## i) Graph for Open Prices

# %%
import plotly.graph_objects as go

plt.figure(figsize=(14, 6))
fig = px.line(LITECOIN.Open,x=LITECOIN.Date, y='Open', labels={'x': 'Date', 'y': 'Price'}, title='Open Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.update_xaxes(tickfont=dict(color='#B468FF'))  # Set x-axis label color to light purple
fig.update_yaxes(tickfont=dict(color='#B468FF'))
fig.update_layout(
    paper_bgcolor='#180736',  # Set the background color to white
    plot_bgcolor='#180736',  # Set the background color to white
    template="plotly_dark"  # Use the "plotly_dark" template
)
fig.update_traces(line=dict(color='#B468FF'))

fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %% [markdown]
# ## i) Graph for High Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(LITECOIN.High,x=LITECOIN.Date, y='High', labels={'x': 'Date', 'y': 'Price'}, title='High Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iii) Graph for Low Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(LITECOIN.Low,x=LITECOIN.Date, y='Low', labels={'x': 'Date', 'y': 'Price'}, title='Low Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iv) Graph for Close Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(LITECOIN.Close,x=LITECOIN.Date, y='Close', labels={'x': 'Date', 'y': 'Price'}, title='Close Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ### Now, creating plots for High and Low Column Values
#
# #### These are subplots

# %%
#Creating Subplots for high and low columns

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# Second subplot (High Price)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['High'], mode='lines', name='High Price'), row=1, col=1)
fig.update_yaxes(title_text="High Price", row=1, col=1)

# Third subplot (Low Price)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['Low'], mode='lines', name='High Price'), row=2, col=1)
fig.update_yaxes(title_text="Low Price", row=2, col=1)

# Fourth subplot(High and Low Prices)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['High'], mode='lines', name='High Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['Low'], mode='lines', name='Low Price'), row=3, col=1)
fig.update_yaxes(title_text="High and Low Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="High, Low and High & Low Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %% [markdown]
# ### Now, subplots for Open and Closed Prices

# %%
#Subplots for open and close prices

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# First subplot (Open Price)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['Open'], mode='lines', name='Open Price'), row=1, col=1)
fig.update_yaxes(title_text="Open Price", row=1, col=1)

# Second subplot (Close Price)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['Close'], mode='lines', name='Close Price'), row=2, col=1)
fig.update_yaxes(title_text="Close Price", row=2, col=1)

# Third subplot(Open and Close Prices)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['Open'], mode='lines', name='Open Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=LITECOIN['Date'], y=LITECOIN['Close'], mode='lines', name='Close Price'), row=3, col=1)
fig.update_yaxes(title_text="Open and Close Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="Open, Close and Open & Close Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %%
# making output column one day ahead of the closing price column
LITECOIN['Target_Price'] = LITECOIN['Close'].shift(-1)
LITECOIN
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 0     2018-09-25  58.021000  58.147598  54.737598  57.537601  351579000
# 1     2018-09-26  57.449200  59.620098  56.701698  57.395500  294136000
# 2     2018-09-27  57.450001  64.294998  56.923901  62.979401  574277000
# 3     2018-09-28  63.171501  64.422600  60.807899  61.895100  459862000
# 4     2018-09-29  61.643501  62.025299  59.491600  61.606899  356028000
# ...          ...        ...        ...        ...        ...        ...
# 1822  2023-09-21  64.565125  64.967659  63.124760  64.690987  270451760
# 1823  2023-09-22  64.691711  65.460808  64.177536  64.335403  278551984
# 1824  2023-09-23  64.334908  65.225388  64.334908  65.080391  240624622
# 1825  2023-09-24  65.080063  65.084198  63.540279  63.587139  189877277
# 1826  2023-09-25  63.580563  64.574844  63.192348  64.310143  217427200
#
#       Target_Price
# 0        57.395500
# 1        62.979401
# 2        61.895100
# 3        61.606899
# 4        61.141899
# ...            ...
# 1822     64.335403
# 1823     65.080391
# 1824     63.587139
# 1825     64.310143
# 1826           NaN
#
# [1827 rows x 7 columns]

# %%
LITECOIN.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    1
# dtype: int64

# %%
LITECOIN.dropna(inplace=True)

# %%
LITECOIN.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    0
# dtype: int64

# %%
# input features
X_LITECOIN=LITECOIN[['Open', 'Close']]

# output features
y_LITECOIN=LITECOIN['Target_Price']

# %% [markdown]
# # Training and Testing the Model
#
# ## We will give 0.10 % data to our model for testing to make accurate and close predictions

# %%
X_LITECOIN_train, X_LITECOIN_test, y_LITECOIN_train, y_LITECOIN_test=train_test_split(X_LITECOIN, y_LITECOIN, test_size=.10, random_state=50)

# %%
model_LITECOIN=LinearRegression()
model_LITECOIN.fit(X_LITECOIN_train, y_LITECOIN_train)
# Out:
# LinearRegression()

# %%
model_LITECOIN.score(X_LITECOIN_test, y_LITECOIN_test)
# Out:
# 0.9945882335867546

# %%
LITECOIN_model=joblib.dump(model_LITECOIN,"LITECOIN_predictions.pkl")

# %%
LITECOIN.tail(1)
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 1825  2023-09-24  65.080063  65.084198  63.540279  63.587139  189877277
#
#       Target_Price
# 1825     64.310143

# %%
LITECOIN_model_predictions=joblib.load("LITECOIN_predictions.pkl")

LITECOIN_last_Open=float(input("Enter the last Open value: "))
print("You entered LITECOIN_last_Open value: ", LITECOIN_last_Open)

LITECOIN_last_Close=float(input("Enter the last Close value: "))
print("You entered LITECOIN_last_Close value: ", LITECOIN_last_Close)
print(" ")

LITECOIN_Input=pd.DataFrame({"Open": [LITECOIN_last_Open], "Close": [LITECOIN_last_Close]})
LITECOIN_future_pred=LITECOIN_model_predictions.predict(LITECOIN_Input)
    
print("Your predicted value of LITECOIN coin is==> ", LITECOIN_future_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alishba athar\OneDrive\Desktop\Crypto\LITECOIN-USD.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/LITECOIN-USD.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> LITECOIN_model_predictions=joblib.load("LITECOIN_predictions.pkl")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/LITECOIN-USD.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> LITECOIN_last_Open=float(input("Enter the last Open value: "))
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/LITECOIN-USD.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> print("You entered LITECOIN_last_Open value: ", LITECOIN_last_Open)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/LITECOIN-USD.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> LITECOIN_last_Close=float(input("Enter the last Close value: "))
#
# ValueError: could not convert string to float: ''
