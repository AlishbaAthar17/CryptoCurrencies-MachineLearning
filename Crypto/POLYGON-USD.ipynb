# %%
#Importing necessary libraries for training the model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # for ploting graphs
import plotly.express as px # for ploting graphs
import plotly.graph_objects as go # for ploting graphs
from plotly.subplots import make_subplots # to create the subplots
from datetime import datetime # for extracting data and time 
from sklearn.model_selection import train_test_split # for separating the training and testing data
from sklearn.linear_model import LinearRegression # for model creation
import joblib # used to save model in .pkl format

# %%
POLYGON = pd.read_csv("MATIC-USD.csv")
POLYGON
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 0     2019-04-28  0.004521  0.004545  0.004317  0.004421   0.004421    8408136
# 1     2019-04-29  0.004418  0.004492  0.003471  0.003471   0.003471    8267044
# 2     2019-04-30  0.003462  0.005078  0.003458  0.004478   0.004478   25072706
# 3     2019-05-01  0.004440  0.004673  0.004071  0.004374   0.004374   10567352
# 4     2019-05-02  0.004366  0.004700  0.004096  0.004198   0.004198    6714908
# ...          ...       ...       ...       ...       ...        ...        ...
# 1607  2023-09-21  0.541485  0.543222  0.519322  0.520152   0.520152  255574808
# 1608  2023-09-22  0.520152  0.524160  0.517455  0.520995   0.520995  167780325
# 1609  2023-09-23  0.520995  0.523029  0.519823  0.520751   0.520751  131725692
# 1610  2023-09-24  0.520761  0.525911  0.512820  0.513589   0.513589  147333782
# 1611  2023-09-25  0.513361  0.516356  0.510117  0.514046   0.514046  189380016
#
# [1612 rows x 7 columns]

# %% [markdown]
# # Pre-processing

# %%
#Dropping unnecessary columns
POLYGON.drop(['Adj Close'], axis=1, inplace=True)
POLYGON
# Out:
#             Date      Open      High       Low     Close     Volume
# 0     2019-04-28  0.004521  0.004545  0.004317  0.004421    8408136
# 1     2019-04-29  0.004418  0.004492  0.003471  0.003471    8267044
# 2     2019-04-30  0.003462  0.005078  0.003458  0.004478   25072706
# 3     2019-05-01  0.004440  0.004673  0.004071  0.004374   10567352
# 4     2019-05-02  0.004366  0.004700  0.004096  0.004198    6714908
# ...          ...       ...       ...       ...       ...        ...
# 1607  2023-09-21  0.541485  0.543222  0.519322  0.520152  255574808
# 1608  2023-09-22  0.520152  0.524160  0.517455  0.520995  167780325
# 1609  2023-09-23  0.520995  0.523029  0.519823  0.520751  131725692
# 1610  2023-09-24  0.520761  0.525911  0.512820  0.513589  147333782
# 1611  2023-09-25  0.513361  0.516356  0.510117  0.514046  189380016
#
# [1612 rows x 6 columns]

# %%
POLYGON.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612 entries, 0 to 1611
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1612 non-null   object
#  1   Open    1612 non-null   float64
#  2   High    1612 non-null   float64
#  3   Low     1612 non-null   float64
#  4   Close   1612 non-null   float64
#  5   Volume  1612 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 75.7+ KB

# %%
POLYGON.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
POLYGON.duplicated().sum()
# Out:
# 0

# %%
POLYGON.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612 entries, 0 to 1611
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1612 non-null   object
#  1   Open    1612 non-null   float64
#  2   High    1612 non-null   float64
#  3   Low     1612 non-null   float64
#  4   Close   1612 non-null   float64
#  5   Volume  1612 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 75.7+ KB

# %% [markdown]
# # Visualizations
#
# ## i) Graph for Open Prices

# %%
plt.figure(figsize=(14, 6))
fig = px.line(POLYGON.Open,x=POLYGON.Date, y='Open', labels={'x': 'Date', 'y': 'Price'}, title='Open Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)

fig.show()

# %% [markdown]
# ## i) Graph for High Column Values

# %%
import plotly.graph_objects as go

plt.figure(figsize=(14, 6))
fig = px.line(POLYGON.High,x=POLYGON.Date, y='High', labels={'x': 'Date', 'y': 'Price'}, title='High Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.update_xaxes(tickfont=dict(color='#B468FF'))  # Set x-axis label color to light purple
fig.update_yaxes(tickfont=dict(color='#B468FF'))
fig.update_layout(
    paper_bgcolor='#180736',  # Set the background color to white
    plot_bgcolor='#180736',  # Set the background color to white
    template="plotly_dark"  # Use the "plotly_dark" template
)
fig.update_traces(line=dict(color='#B468FF'))

fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %% [markdown]
# ## iii) Graph for Low Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(POLYGON.Low,x=POLYGON.Date, y='Low', labels={'x': 'Date', 'y': 'Price'}, title='Low Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iv) Graph for Close Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(POLYGON.Close,x=POLYGON.Date, y='Close', labels={'x': 'Date', 'y': 'Price'}, title='Close Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ### Now, creating plots for High and Low Column Values
#
# #### These are subplots

# %%
#Creating Subplots for high and low columns

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# Second subplot (High Price)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['High'], mode='lines', name='High Price'), row=1, col=1)
fig.update_yaxes(title_text="High Price", row=1, col=1)

# Third subplot (Low Price)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['Low'], mode='lines', name='High Price'), row=2, col=1)
fig.update_yaxes(title_text="Low Price", row=2, col=1)

# Fourth subplot(High and Low Prices)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['High'], mode='lines', name='High Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['Low'], mode='lines', name='Low Price'), row=3, col=1)
fig.update_yaxes(title_text="High and Low Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="High, Low and High & Low Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %% [markdown]
# ### Now, subplots for Open and Closed Prices

# %%
#Subplots for open and close prices

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# First subplot (Open Price)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['Open'], mode='lines', name='Open Price'), row=1, col=1)
fig.update_yaxes(title_text="Open Price", row=1, col=1)

# Second subplot (Close Price)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['Close'], mode='lines', name='Close Price'), row=2, col=1)
fig.update_yaxes(title_text="Close Price", row=2, col=1)

# Third subplot(Open and Close Prices)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['Open'], mode='lines', name='Open Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=POLYGON['Date'], y=POLYGON['Close'], mode='lines', name='Close Price'), row=3, col=1)
fig.update_yaxes(title_text="Open and Close Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="Open, Close and Open & Close Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %%
# making output column one day ahead of the closing price column
POLYGON['Target_Price'] = POLYGON['Close'].shift(-1)
POLYGON
# Out:
#             Date      Open      High       Low     Close     Volume  \
# 0     2019-04-28  0.004521  0.004545  0.004317  0.004421    8408136
# 1     2019-04-29  0.004418  0.004492  0.003471  0.003471    8267044
# 2     2019-04-30  0.003462  0.005078  0.003458  0.004478   25072706
# 3     2019-05-01  0.004440  0.004673  0.004071  0.004374   10567352
# 4     2019-05-02  0.004366  0.004700  0.004096  0.004198    6714908
# ...          ...       ...       ...       ...       ...        ...
# 1607  2023-09-21  0.541485  0.543222  0.519322  0.520152  255574808
# 1608  2023-09-22  0.520152  0.524160  0.517455  0.520995  167780325
# 1609  2023-09-23  0.520995  0.523029  0.519823  0.520751  131725692
# 1610  2023-09-24  0.520761  0.525911  0.512820  0.513589  147333782
# 1611  2023-09-25  0.513361  0.516356  0.510117  0.514046  189380016
#
#       Target_Price
# 0         0.003471
# 1         0.004478
# 2         0.004374
# 3         0.004198
# 4         0.004256
# ...            ...
# 1607      0.520995
# 1608      0.520751
# 1609      0.513589
# 1610      0.514046
# 1611           NaN
#
# [1612 rows x 7 columns]

# %%
POLYGON.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    1
# dtype: int64

# %%
POLYGON.dropna(inplace=True)

# %%
POLYGON.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    0
# dtype: int64

# %%
# input features
X_POLYGON=POLYGON[['Open', 'Close']]

# output features
y_POLYGON=POLYGON['Target_Price']

# %% [markdown]
# # Training and Testing the Model
#
# ## We will give 0.10 % data to our model for testing to make accurate and close predictions

# %%
X_POLYGON_train, X_POLYGON_test, y_POLYGON_train, y_POLYGON_test=train_test_split(X_POLYGON, y_POLYGON, test_size=.10, random_state=50)

# %%
model_POLYGON=LinearRegression()
model_POLYGON.fit(X_POLYGON_train, y_POLYGON_train)
# Out:
# LinearRegression()

# %%
model_POLYGON.score(X_POLYGON_test, y_POLYGON_test)
# Out:
# 0.9900810553139335

# %%
POLYGON_model=joblib.dump(model_POLYGON,"POLYGON_predictions.pkl")

# %%
POLYGON.tail(1)
# Out:
#             Date      Open      High      Low     Close     Volume  \
# 1610  2023-09-24  0.520761  0.525911  0.51282  0.513589  147333782
#
#       Target_Price
# 1610      0.514046

# %%
POLYGON_model_predictions=joblib.load("POLYGON_predictions.pkl")

POLYGON_last_Open=float(input("Enter the last Open value: "))
print("You entered POLYGON_last_Open value: ", POLYGON_last_Open)

POLYGON_last_Close=float(input("Enter the last Close value: "))
print("You entered POLYGON_last_Close value: ", POLYGON_last_Close)
print(" ")

POLYGON_Input=pd.DataFrame({"Open": [POLYGON_last_Open], "Close": [POLYGON_last_Close]})
POLYGON_future_pred=POLYGON_model_predictions.predict(POLYGON_Input)
    
print("Your predicted value of POLYGON coin is==> ", POLYGON_future_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alishba athar\OneDrive\Desktop\Crypto\POLYGON-USD.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLYGON-USD.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> POLYGON_model_predictions=joblib.load("POLYGON_predictions.pkl")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLYGON-USD.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> POLYGON_last_Open=float(input("Enter the last Open value: "))
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLYGON-USD.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> print("You entered POLYGON_last_Open value: ", POLYGON_last_Open)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/POLYGON-USD.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> POLYGON_last_Close=float(input("Enter the last Close value: "))
#
# ValueError: could not convert string to float: ''
