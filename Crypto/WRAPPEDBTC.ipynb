# %%
#Importing necessary libraries for training the model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # for ploting graphs
import plotly.express as px # for ploting graphs
import plotly.graph_objects as go # for ploting graphs
from plotly.subplots import make_subplots # to create the subplots
from datetime import datetime # for extracting data and time 
from sklearn.model_selection import train_test_split # for separating the training and testing data
from sklearn.linear_model import LinearRegression # for model creation
import joblib # used to save model in .pkl format

# %%
WBTC = pd.read_csv("WBTC-USD.csv")
WBTC
# Out:
#             Date          Open          High           Low         Close  \
# 0     2019-01-30   3494.277588   3502.762939   3477.248047   3496.455322
# 1     2019-01-31   3496.839844   3535.421143   3435.290527   3466.506592
# 2     2019-02-01   3469.393066   3517.770264   3422.825684   3480.772217
# 3     2019-02-02   3476.335205   3546.404297   3459.112793   3542.095459
# 4     2019-02-03   3540.562744   3544.666992   3436.177734   3477.865967
# ...          ...           ...           ...           ...           ...
# 1696  2023-09-22  26551.201172  26678.257813  26517.824219  26570.835938
# 1697  2023-09-23  26572.302734  26595.724609  26541.410156  26559.427734
# 1698  2023-09-24  26559.103516  26661.742188  26252.396484  26255.166016
# 1699  2023-09-25  26255.042969  26365.498047  26037.025391  26290.861328
# 1700  2023-09-26  26289.955078  26340.644531  26138.779297  26145.843750
#
#          Adj Close     Volume
# 0      3496.455322       1475
# 1      3466.506592      19289
# 2      3480.772217      13640
# 3      3542.095459       1895
# 4      3477.865967       6525
# ...            ...        ...
# 1696  26570.835938   72910450
# 1697  26559.427734   58329073
# 1698  26255.166016   62829730
# 1699  26290.861328   86862912
# 1700  26145.843750  148490608
#
# [1701 rows x 7 columns]

# %% [markdown]
# # Pre-processing

# %%
#Dropping unnecessary columns
WBTC.drop(['Adj Close'], axis=1, inplace=True)
WBTC
# Out:
#             Date          Open          High           Low         Close  \
# 0     2019-01-30   3494.277588   3502.762939   3477.248047   3496.455322
# 1     2019-01-31   3496.839844   3535.421143   3435.290527   3466.506592
# 2     2019-02-01   3469.393066   3517.770264   3422.825684   3480.772217
# 3     2019-02-02   3476.335205   3546.404297   3459.112793   3542.095459
# 4     2019-02-03   3540.562744   3544.666992   3436.177734   3477.865967
# ...          ...           ...           ...           ...           ...
# 1696  2023-09-22  26551.201172  26678.257813  26517.824219  26570.835938
# 1697  2023-09-23  26572.302734  26595.724609  26541.410156  26559.427734
# 1698  2023-09-24  26559.103516  26661.742188  26252.396484  26255.166016
# 1699  2023-09-25  26255.042969  26365.498047  26037.025391  26290.861328
# 1700  2023-09-26  26289.955078  26340.644531  26138.779297  26145.843750
#
#          Volume
# 0          1475
# 1         19289
# 2         13640
# 3          1895
# 4          6525
# ...         ...
# 1696   72910450
# 1697   58329073
# 1698   62829730
# 1699   86862912
# 1700  148490608
#
# [1701 rows x 6 columns]

# %%
WBTC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1701 entries, 0 to 1700
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1701 non-null   object
#  1   Open    1701 non-null   float64
#  2   High    1701 non-null   float64
#  3   Low     1701 non-null   float64
#  4   Close   1701 non-null   float64
#  5   Volume  1701 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 79.9+ KB

# %%
WBTC.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
WBTC.duplicated().sum()
# Out:
# 0

# %%
WBTC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1701 entries, 0 to 1700
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1701 non-null   object
#  1   Open    1701 non-null   float64
#  2   High    1701 non-null   float64
#  3   Low     1701 non-null   float64
#  4   Close   1701 non-null   float64
#  5   Volume  1701 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 79.9+ KB

# %% [markdown]
# # Visualizations
#
# ## i) Graph for Open Prices

# %%
import plotly.graph_objects as go

plt.figure(figsize=(14, 6))
fig = px.line(WBTC.Open,x=WBTC.Date, y='Open', labels={'x': 'Date', 'y': 'Price'}, title='Open Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.update_xaxes(tickfont=dict(color='#B468FF'))  # Set x-axis label color to light purple
fig.update_yaxes(tickfont=dict(color='#B468FF'))
fig.update_layout(
    paper_bgcolor='#180736',  # Set the background color to white
    plot_bgcolor='#180736',  # Set the background color to white
    template="plotly_dark"  # Use the "plotly_dark" template
)
fig.update_traces(line=dict(color='#B468FF'))

fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %% [markdown]
# ## i) Graph for High Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(WBTC.High,x=WBTC.Date, y='High', labels={'x': 'Date', 'y': 'Price'}, title='High Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iii) Graph for Low Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(WBTC.Low,x=WBTC.Date, y='Low', labels={'x': 'Date', 'y': 'Price'}, title='Low Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ## iv) Graph for Close Column Values

# %%
plt.figure(figsize=(14, 6))
fig = px.line(WBTC.Close,x=WBTC.Date, y='Close', labels={'x': 'Date', 'y': 'Price'}, title='Close Price Over Time')
fig.update_xaxes(type='category')  # Ensure the x-axis treats the index as categorical (date)
fig.show()

# %% [markdown]
# ### Now, creating plots for High and Low Column Values
#
# #### These are subplots

# %%
#Creating Subplots for high and low columns

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# Second subplot (High Price)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['High'], mode='lines', name='High Price'), row=1, col=1)
fig.update_yaxes(title_text="High Price", row=1, col=1)

# Third subplot (Low Price)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['Low'], mode='lines', name='High Price'), row=2, col=1)
fig.update_yaxes(title_text="Low Price", row=2, col=1)

# Fourth subplot(High and Low Prices)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['High'], mode='lines', name='High Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['Low'], mode='lines', name='Low Price'), row=3, col=1)
fig.update_yaxes(title_text="High and Low Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="High, Low and High & Low Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %% [markdown]
# ### Now, subplots for Open and Closed Prices

# %%
#Subplots for open and close prices

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.1)

# First subplot (Open Price)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['Open'], mode='lines', name='Open Price'), row=1, col=1)
fig.update_yaxes(title_text="Open Price", row=1, col=1)

# Second subplot (Close Price)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['Close'], mode='lines', name='Close Price'), row=2, col=1)
fig.update_yaxes(title_text="Close Price", row=2, col=1)

# Third subplot(Open and Close Prices)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['Open'], mode='lines', name='Open Price'), row=3, col=1)
fig.add_trace(go.Scatter(x=WBTC['Date'], y=WBTC['Close'], mode='lines', name='Close Price'), row=3, col=1)
fig.update_yaxes(title_text="Open and Close Price", row=3, col=1)

# setting up the title and size of the graph
fig.update_layout(title_text="Open, Close and Open & Close Prices Over Time for BTC",
    height=500,  # Set the height
    width=1000) # width
fig.show()

# %%
# making output column one day ahead of the closing price column
WBTC['Target_Price'] = WBTC['Close'].shift(-1)
WBTC
# Out:
#             Date          Open          High           Low         Close  \
# 0     2019-01-30   3494.277588   3502.762939   3477.248047   3496.455322
# 1     2019-01-31   3496.839844   3535.421143   3435.290527   3466.506592
# 2     2019-02-01   3469.393066   3517.770264   3422.825684   3480.772217
# 3     2019-02-02   3476.335205   3546.404297   3459.112793   3542.095459
# 4     2019-02-03   3540.562744   3544.666992   3436.177734   3477.865967
# ...          ...           ...           ...           ...           ...
# 1696  2023-09-22  26551.201172  26678.257813  26517.824219  26570.835938
# 1697  2023-09-23  26572.302734  26595.724609  26541.410156  26559.427734
# 1698  2023-09-24  26559.103516  26661.742188  26252.396484  26255.166016
# 1699  2023-09-25  26255.042969  26365.498047  26037.025391  26290.861328
# 1700  2023-09-26  26289.955078  26340.644531  26138.779297  26145.843750
#
#          Volume  Target_Price
# 0          1475   3466.506592
# 1         19289   3480.772217
# 2         13640   3542.095459
# 3          1895   3477.865967
# 4          6525   3481.219238
# ...         ...           ...
# 1696   72910450  26559.427734
# 1697   58329073  26255.166016
# 1698   62829730  26290.861328
# 1699   86862912  26145.843750
# 1700  148490608           NaN
#
# [1701 rows x 7 columns]

# %%
WBTC.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    1
# dtype: int64

# %%
WBTC.dropna(inplace=True)

# %%
WBTC.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Target_Price    0
# dtype: int64

# %%
# input features
X_WBTC=WBTC[['Open', 'Close']]

# output features
y_WBTC=WBTC['Target_Price']

# %% [markdown]
# # Training and Testing the Model
#
# ## We will give 0.10 % data to our model for testing to make accurate and close predictions

# %%
X_WBTC_train, X_WBTC_test, y_WBTC_train, y_WBTC_test=train_test_split(X_WBTC, y_WBTC, test_size=.10, random_state=50)

# %%
model_WBTC=LinearRegression()
model_WBTC.fit(X_WBTC_train, y_WBTC_train)
# Out:
# LinearRegression()

# %%
model_WBTC.score(X_WBTC_test, y_WBTC_test)
# Out:
# 0.9960660091425603

# %%
WBTC_model=joblib.dump(model_WBTC,"WBTC_predictions.pkl")

# %%
WBTC.tail(1)
# Out:
#             Date          Open          High           Low         Close  \
# 1699  2023-09-25  26255.042969  26365.498047  26037.025391  26290.861328
#
#         Volume  Target_Price
# 1699  86862912   26145.84375

# %%
WBTC_model_predictions=joblib.load("WBTC_predictions.pkl")

WBTC_last_Open=float(input("Enter the last Open value: "))
print("You entered WBTC_last_Open value: ", WBTC_last_Open)

WBTC_last_Close=float(input("Enter the last Close value: "))
print("You entered WBTC_last_Close value: ", WBTC_last_Close)
print(" ")

WBTC_Input=pd.DataFrame({"Open": [WBTC_last_Open], "Close": [WBTC_last_Close]})
WBTC_future_pred=WBTC_model_predictions.predict(WBTC_Input)
    
print("Your predicted value of WBTC coin is==> ", WBTC_future_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alishba athar\OneDrive\Desktop\Crypto\WRAPPEDBTC.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/WRAPPEDBTC.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> WBTC_model_predictions=joblib.load("WBTC_predictions.pkl")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/WRAPPEDBTC.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> WBTC_last_Open=float(input("Enter the last Open value: "))
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/WRAPPEDBTC.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> print("You entered WBTC_last_Open value: ", WBTC_last_Open)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alishba%20athar/OneDrive/Desktop/Crypto/WRAPPEDBTC.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> WBTC_last_Close=float(input("Enter the last Close value: "))
#
# ValueError: could not convert string to float: ''
